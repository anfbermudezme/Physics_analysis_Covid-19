# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv'
df = pd.read_csv(url,index_col=0,parse_dates=[0])

# %%
df.head(10)
# Out:
#             iso_code        date  total_vaccinations  people_vaccinated  \
# location
# Afghanistan      AFG  2021-02-22                 0.0                0.0
# Afghanistan      AFG  2021-02-23                 NaN                NaN
# Afghanistan      AFG  2021-02-24                 NaN                NaN
# Afghanistan      AFG  2021-02-25                 NaN                NaN
# Afghanistan      AFG  2021-02-26                 NaN                NaN
# Afghanistan      AFG  2021-02-27                 NaN                NaN
# Afghanistan      AFG  2021-02-28              8200.0             8200.0
# Afghanistan      AFG  2021-03-01                 NaN                NaN
# Afghanistan      AFG  2021-03-02                 NaN                NaN
# Afghanistan      AFG  2021-03-03                 NaN                NaN
#
#              people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# location
# ...

# %%
world_table = df.loc[df.loc[:,'iso_code']=='OWID_WRL']

# %%
df.loc[df.loc[:,'iso_code']=='OWID_WRL']
# Out:
#           iso_code        date  total_vaccinations  people_vaccinated  \
# location
# World     OWID_WRL  2020-12-02        0.000000e+00       0.000000e+00
# World     OWID_WRL  2020-12-03        0.000000e+00       0.000000e+00
# World     OWID_WRL  2020-12-04        1.000000e+00       1.000000e+00
# World     OWID_WRL  2020-12-05        1.000000e+00       1.000000e+00
# World     OWID_WRL  2020-12-06        1.000000e+00       1.000000e+00
# ...            ...         ...                 ...                ...
# World     OWID_WRL  2022-06-12        1.195142e+10       5.214874e+09
# World     OWID_WRL  2022-06-13        1.195622e+10       5.215406e+09
# World     OWID_WRL  2022-06-14        1.196331e+10       5.217266e+09
# World     OWID_WRL  2022-06-15        1.197582e+10       5.218865e+09
# World     OWID_WRL  2022-06-16        1.197913e+10       5.219265e+09
#
#           people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# location
# ...

# %%
data = {'date': list(world_table['date']),
        'total_vaccinations': list(world_table['total_vaccinations']),
        'people_vaccinated': list(world_table['people_vaccinated']),
        'people_fully_vaccinated': list(world_table['people_fully_vaccinated'])}

# %%
DataFrame = pd.DataFrame(
    data,
    columns=[
        'date',
        'total_vaccinations',
        'people_vaccinated',
        'people_fully_vaccinated',
    ]
)

# %%
DataFrame
# Out:
#            date  total_vaccinations  people_vaccinated  \
# 0    2020-12-02        0.000000e+00       0.000000e+00
# 1    2020-12-03        0.000000e+00       0.000000e+00
# 2    2020-12-04        1.000000e+00       1.000000e+00
# 3    2020-12-05        1.000000e+00       1.000000e+00
# 4    2020-12-06        1.000000e+00       1.000000e+00
# ..          ...                 ...                ...
# 557  2022-06-12        1.195142e+10       5.214874e+09
# 558  2022-06-13        1.195622e+10       5.215406e+09
# 559  2022-06-14        1.196331e+10       5.217266e+09
# 560  2022-06-15        1.197582e+10       5.218865e+09
# 561  2022-06-16        1.197913e+10       5.219265e+09
#
#      people_fully_vaccinated
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 557             4.764367e+09
# 558             4.765671e+09
# 559             4.767738e+09
# ...

# %%
DataFrame.to_excel(r'world_vaccination.xlsx', index = False)

# %%
DeathsVaccination = pd.read_excel('WorldVaccinationDeathsRelation.xlsx')

# %%
x = np.arange(0, 562, 1)
y1 = DeathsVaccination['total_vaccinations']
y2 = DeathsVaccination['people_vaccinated']
y3 = DeathsVaccination['people_fully_vaccinated']

# %%
fig, ax = plt.subplots()
ax.plot(x, y1,'r--', label = "total Vaccinations")
ax.plot(x, y2,'k--', label = "people Vaccinated")
ax.plot(x, y3,'g--', label = "people Fully Vaccinated")
ax.legend(loc="upper left")
ax.set_xlabel("Date")
ax.set_ylabel("Agents")
plt.grid()

# %%
CorrelationLagDays = pd.read_excel('CorrelationVaccination.xlsx')
CorrelationLagDays
# Out:
#      Days_Lag  Correlation  Correlation_Norm_MA
# 0           1     0.294900             0.296451
# 1           2     0.253280             0.296944
# 2           3     0.236147             0.297225
# 3           4     0.245067             0.297330
# 4           5     0.269233             0.297230
# ..        ...          ...                  ...
# 725       726    -0.809090            -0.936004
# 726       727    -0.804873            -0.936145
# 727       728    -0.812620            -0.935709
# 728       729    -0.822242            -0.934898
# 729       730    -0.830020            -0.933798
#
# [730 rows x 3 columns]

# %%
x = CorrelationLagDays['Days_Lag']
y1 = CorrelationLagDays['Correlation']
y2 = CorrelationLagDays['Correlation_Norm_MA']

# %%
fig, ax = plt.subplots()
ax.plot(x, y1,'b--', label = "Correlation")
ax.plot(x, y2,'k--', label = "Correlation_Norm_MA")
ax.legend(loc="upper left")
ax.set_xlabel("Date")
ax.set_ylabel("Correlation")
plt.grid()
